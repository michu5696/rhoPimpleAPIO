# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

# %%
fig,ax=plt.subplots()
data=[98.24,49.41]
labels=["48 (single-node)","96 (double-node)"]
ax.bar(labels,data,width=0.5,align="center")
ax.set_ylabel("overlap (%)")
ax.set_xlabel("# procs")
ax.set_title("32 million cell test on MN")
# Out:
# Text(0.5, 1.0, '32 million cell test on MN')

# %%
fig,ax=plt.subplots()
data=[49.04,55.14]
labels=["96 (2 nodes)","144 (3 nodes)"]
ax.bar(labels,data)
ax.set_ylabel("overlap (%)")
ax.set_xlabel("# procs")
ax.set_title("64 million cell test on MN")
# Out:
# Text(0.5, 1.0, '64 million cell test on MN')
