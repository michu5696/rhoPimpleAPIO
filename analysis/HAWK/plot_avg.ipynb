# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

# %%
fig,ax=plt.subplots()
data=[39.71,43.05,43.51]
labels=["256","512","1024"]
ax.bar(labels,data)
ax.set_ylabel("overlap (%)")
ax.set_xlabel("# procs")
ax.set_title("32 million cell test on Hawk")
# Out:
# Text(0.5, 1.0, '32 million cell test on Hawk')

# %%
fig,ax=plt.subplots()
data=[39.91,41.29,45.16]
labels=["512","1024","2048"]
ax.bar(labels,data)
ax.set_ylabel("overlap (%)")
ax.set_xlabel("# procs")
ax.set_title("64 million cell test on Hawk")
# Out:
# Text(0.5, 1.0, '64 million cell test on Hawk')

# %%
fig,ax=plt.subplots()
data=[43.54,25.87,45.99]
labels=["1024","2048","4096"]
ax.bar(labels,data)
ax.set_ylabel("overlap (%)")
ax.set_xlabel("# procs")
ax.set_title("128 million cell test on Hawk")
# Out:
# Text(0.5, 1.0, '128 million cell test on Hawk')
