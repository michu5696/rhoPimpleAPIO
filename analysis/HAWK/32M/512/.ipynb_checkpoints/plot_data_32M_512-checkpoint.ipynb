# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
apio_io=np.loadtxt("apio_io.dat")
orig_io=np.loadtxt("orig_io.dat")
x_apio=np.linspace(0,len(apio_io),len(apio_io))
x_orig=np.linspace(0,len(orig_io),len(orig_io))
#apio_io=apio_io[:-2]

# %%
len(orig_io)
# Out:
# 17

# %%
#diff=orig_io-apio_io
#apio_io=apio_io[diff>0]
#orig_io=orig_io[diff>0]
plt.plot(x_apio,apio_io, label="APIO")
plt.plot(x_orig,orig_io,label="ORIG")
plt.legend()

# %%
vec=(orig_io-apio_io[:-2])*100/orig_io
plt.plot(vec)

# %%
orig_io_step=np.loadtxt("orig_io_step.dat")
orig_comp_step=np.loadtxt("orig_comp_step.dat")
orig_comp_step=orig_comp_step[:-2]

# %%
len(orig_comp_step)
# Out:
# 1810

# %%
vec=(orig_comp_step/orig_io_step)*100
plt.plot(vec)

# %%
iterno=np.loadtxt("iterno.dat")
